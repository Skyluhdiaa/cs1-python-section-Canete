# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyluhdiaa/cs1-python-section-Canete/blob/main/COMSCI_ACTIVITIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ask the user to input three numbers
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
num3 = int(input("Enter third number:"))

# Compare the numbers to find the biggest
biggest = num1

if num2 > biggest:
  biggest = num2

if num3 > biggest:
  biggest = num3

print("The biggest number is:", biggest)
# Out:
# Enter first number:2
# Enter second number:4
# Enter third number:3
# The biggest number is: 4
